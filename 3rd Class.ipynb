# %%
4.0 == 5.0
# Out:
# False

# %%
4.0 == 4.0
# Out:
# True

# %%
x = 67
isinstance(x,int)
# Out:
# True

# %%
type(x)
# Out:
# int

# %%
a = 100 
b = 200
a and b and ""
# Out:
# ''

# %%
x =-100
from math import sqrt
x > 0 and sqrt(x)
# Out:
# False

# %%
id(x)
# Out:
# 2687502995248

# %%
y = x 
y is x 
id(x) == id(y)
# Out:
# True

# %%
id(y)
# Out:
# 2687502995248

# %%
id(x)
# Out:
# 2687502995248

# %%
z =10
id(z)
# Out:
# 140734604555464

# %%
z == x
# Out:
# False

# %%
name = "Faizan"

# %%
name
# Out:
# 'Faizan'

# %%
age = 50
age
# Out:
# 50

# %% [markdown]
# ![image.png](attachment:2a7a264e-4fb1-4499-b58d-69991c66dce5.png)

# %%
1faizan = "Faian"
# Out:
#   Cell In[18], line 1
#     1faizan = "Faian"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "Ali"

# %%
name1
# Out:
# 'Ali'

# %% [markdown]
# # Python string

# %%
 # - string is immutable

# %%
text = "Tum bhut ache bachay hu "
type(text)
# Out:
# str

# %%
text.capitalize()
# Out:
# 'Tum bhut ache bachay hu '

# %%
text.count("a")
# Out:
# 3

# %%
text.upper()
# Out:
# 'TUM BHUT ACHE BACHAY HU '

# %%
text.find("a")
# Out:
# 9

# %%
text.strip()   # removing space
# Out:
# 'Tum bhut ache bachay hu'

# %%
text.replace(" " , "")
# Out:
# 'Tumbhutachebachayhu'

# %% [markdown]
# # string format string concatenate(join)

# %%
first_name = "Syed Muhammad "
last_name = "Faizan"
Full_Name = first_name + last_name

# %%
Full_Name
# Out:
# 'Syed Muhammad Faizan'

# %%
Full_Name = first_name + " " +  last_name

# %%
Full_Name
# Out:
# 'Syed Muhammad  Faizan'

# %%
print( input ("What is Your name ? : "))
# Out:
# What is Your name ? :  faizan
# faizan

# %%
name
# Out:
# 'Talha'

# %%
print( int(input("What is Your age ? ")))
# Out:
# What is Your age ?  56
# 56

# %%
age
# Out:
# 56

# %% [markdown]
# # f string

# %%
name = input("Kiya nam hai apka ? ")
age = int(input("kiya age hai apkey ? "))
city = input("kha rehtey hu ap " )
 print(f"uska nam {name} hai , uskey umar {age} hai , uskey city {city} hai ")
# Out:
#   Cell In[4], line 4
#     print(f"uska nam {name} hai , uskey umar {age} hai , uskey city {city} hai ")
#     ^
# IndentationError: unexpected indent

# %%
# Out:
# uska nam Faizan hai , uskey umar 23 hai , uskey city karachi hai

# %%
"Mera nam {name} hai or marey umar{age}".format(name,age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 "Mera nam {name} hai or marey umar{age}".format(name,age)
#
# NameError: name 'name' is not defined

# %% [markdown]
# ## Class Work

# %% [markdown]
# # Concortination Methods

# %%
F_name = input("Enter Your First Name : ")
L_name = input("Enter Your Last name : ")
# Methodd 01
print(f"Mera first name {F_name} hai or last name {L_name} hai Mera pora name {F_name+ " "+L_name}")
# Method 2
print(F_name + " "+ L_name)
# Method 3 
print("{0} {1}".format(F_name , L_name))
# Out:
# Enter Your First Name :  Muhammad
# Enter Your Last name :  Faizan
# Mera first name Muhammad  hai or last name Faizan hai Mera pora name Muhammad  Faizan
# Muhammad  Faizan
# Muhammad  Faizan

# %% [markdown]
# ## Methods of string

# %%
"FAIZAN".lower()
# Out:
# 'faizan'

# %%
"faizan".title()
# Out:
# 'Faizan'

# %%
"faizan".replace("a" , "i")
# Out:
# 'fiizin'

# %%
"ali Khan".find("n")
# Out:
# 7

# %%
"kal mai picnic pr ja rha hu ".index("u")
# Out:
# 26

# %%
"My name is Faizan".split()
# Out:
# ['My', 'name', 'is', 'Faizan']

# %%
"Hello Dear kya haal hain ?".endswith("?")
# Out:
# True

# %%
"Syed Muhammad Faizan".isspace()
# Out:
# False
