# %% [markdown]
# # 2nd Class

# %%
print ("Faizan" , "Fatima" , "Anabia" , sep = " ")
# Out:
# Faizan Fatima Anabia

# %%
# float division
print(8/2)
# Out:
# 4.0

# %%
# floor division 
print(8//2)
# Out:
# 4

# %%
print(4%11)
# Out:
# 4

# %%
print(67>=34)
# Out:
# True

# %%
5<3
# Out:
# False

# %%
"Hello"
# Out:
# 'Hello'

# %%
3 and 6
# Out:
# 6

# %%
4 or 0
# Out:
# 4

# %%
0 and 7
# Out:
# 0
