# %% [markdown]
# # This is our first class

# %%
print("Faizan") #this is code cell
# Out:
# Faizan

# %%
This is row cell and you can add simple plan text here......

# %% [markdown]
# - ESC + M ( to convert cell into markdown)
# - ESC + R ( to convert cell into code )
# - ESC + Y ( to convert cell into code )
# - ESC + A ( to create cell above the present cell )
# - ESC + B ( to create cell below the present cell )

# %% [markdown]
# #### Faizan

# %% [markdown]
# ## This is level Two Heading

# %%
print("My Name is Faizan ........")
# Out:
# My Name is Faizan ........

# %%
x  = 5
type(x)
id(x) # to get the adress
# Out:
# 140736073413672

# %%
x = "Faizan"
type(x)
# Out:
# str

# %%
x = "5"
type(x)
# Out:
# str

# %%
x = 5.6
type(x)
# Out:
# float

# %%
x = True
type(x)
# Out:
# bool

# %%
print("My name is Nabeel")
# Out:
# My name is Nabeel

# %%
# may apna nam likh rha hu idhr 
print("Mera nam Faizan hai  mai 23 saal ka hu ")
# Out:
# Mera nam Faizan hai 	 mai 23 saal ka hu

# %%
name1 = (input("what is your name"))
name2 = (input("what is your last name"))
print (name1)
print (name2)
# Out:
# what is your name nabeel
# what is your last name nabeel
# nabeel
# nabeel

# %%
2%5
# Out:
# 2

# %%
7 // 2 # floor operator
# Out:
# 3

# %%
(((4+5)**2)*4) / 5+(3-2)
# Out:
# 65.8

# %%
x = 6
x1 =7
x += x1

# %%
x
# Out:
# 13

# %%
x == x1
# Out:
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 - hy
#       2 - jnjn
#
# NameError: name 'hy' is not defined
